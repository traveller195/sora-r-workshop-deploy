# %%
Sys.getenv()
# Out:
# __EGL_VENDOR_LIBRARY_FILENAMES
#                         /p/software/jsccloud/stages/2025/software/OpenGL/2024a-GCCcore-13.3.0/share/glvnd/egl_vendor.d/10_nvidia.json:/p/software/jsccloud/stages/2025/software/OpenGL/2024a-GCCcore-13.3.0/share/glvnd/egl_vendor.d/50_mesa.json
# __LMOD_REF_COUNT_ACLOCAL_PATH
# ...

# %%
Sys.getenv("SORA_API_KEY")
# Out:
# [1] "9448b1d9c90db35d8975c24f71c60ee0c2855ee6eaf92eea2a32c23f094331d4de6579c54e51b223658f6769939e64d1380b30f9805bfc9316bef9a7a3ef6217"

# %%
installed.packages()
# Out:
#                Package
# backports      backports
# brew           brew
# codetools      codetools
# collections    collections
# cyclocomp      cyclocomp
# IRdisplay      IRdisplay
# IRkernel       IRkernel
# languageserver languageserver
# lazyeval       lazyeval
# lintr          lintr
# pbdZMQ         pbdZMQ
# R.cache        R.cache
# R.methodsS3    R.methodsS3
# R.oo           R.oo
# R.utils        R.utils
# repr           repr
# rex            rex
# styler         styler
# uuid           uuid
# xmlparsedata   xmlparsedata
# askpass        askpass
# base           base
# base64enc      base64enc
# brew           brew
# brio           brio
# bslib          bslib
# cachem         cachem
# callr          callr
# cli            cli
# clipr          clipr
# ⋮              ⋮
# sessioninfo    sessioninfo
# shiny          shiny
# sourcetools    sourcetools
# splines        splines
# stats          stats
# stats4         stats4
# stringi        stringi
# stringr        stringr
# ...

# %%
installed.packages(lib="~/Rlibs")
# Out:
#                   Package           LibPath Version Priority
# crosstalk         crosstalk         ~/Rlibs 1.2.1   NA
# farver            farver            ~/Rlibs 2.1.2   NA
# ggplot2           ggplot2           ~/Rlibs 3.5.2   NA
# gtable            gtable            ~/Rlibs 0.3.6   NA
# isoband           isoband           ~/Rlibs 0.2.7   NA
# labeling          labeling          ~/Rlibs 0.4.3   NA
# lattice           lattice           ~/Rlibs 0.22-7  recommended
# leaflet.providers leaflet.providers ~/Rlibs 2.0.0   NA
# MASS              MASS              ~/Rlibs 7.3-65  recommended
# Matrix            Matrix            ~/Rlibs 1.7-3   recommended
# mgcv              mgcv              ~/Rlibs 1.9-3   recommended
# nlme              nlme              ~/Rlibs 3.1-168 recommended
# png               png               ~/Rlibs 0.1-8   NA
# RColorBrewer      RColorBrewer      ~/Rlibs 1.1-3   NA
# scales            scales            ~/Rlibs 1.4.0   NA
# ...

# %%
library("ggplot2", lib="~/Rlibs")
# Out:
# Error: package or namespace load failed for ‘ggplot2’:
#  .onLoad failed in loadNamespace() for 'scales', details:
#   call: loadNamespace(x)
#   error: there is no package called ‘farver’
# Traceback:
#
# 1. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return && !quietly)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. value[[3L]](cond)
# ...
